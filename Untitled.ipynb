# %%
# pip install fredapi
# pip install -U python-dotenv

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from fredapi import Fred
from dotenv import load_dotenv

# %%
fred_api_key=os.environ.get('fred-api-key')

# %%
#Create the fred object to pull all the data

# %%
fred=Fred(api_key=fred_api_key)

# %%
#Search fred for economic data and pull down actual data

# %%
sp_search=fred.search("S&P", order_by="popularity")

# %%
sp_search
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2024-02-21   2024-02-21
# CSUSHPINSA              CSUSHPINSA     2024-02-21   2024-02-21
# SP500                        SP500     2024-02-21   2024-02-21
# MEHOINUSA672N        MEHOINUSA672N     2024-02-21   2024-02-21
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2024-02-21   2024-02-21
# ...                            ...            ...          ...
# HCIYISITA066NRUG  HCIYISITA066NRUG     2024-02-21   2024-02-21
# XRNCUSTHA618NRUG  XRNCUSTHA618NRUG     2024-02-21   2024-02-21
# DDEM01GBA156NWDB  DDEM01GBA156NWDB     2024-02-21   2024-02-21
# PLICPPSGA670NRUG  PLICPPSGA670NRUG     2024-02-21   2024-02-21
# RKNANPLCA666NRUG  RKNANPLCA666NRUG     2024-02-21   2024-02-21
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# ...

# %%
sp_search.shape
# Out:
# (1000, 15)

# %%
#get one of the series id raw data with dates and price.

# %%
sp500 = fred.get_series(series_id="SP500")

# %%
#returns pandas series
sp500
# Out:
# 2014-02-21    1836.25
# 2014-02-24    1847.61
# 2014-02-25    1845.12
# 2014-02-26    1845.16
# 2014-02-27    1854.29
#                ...
# 2024-02-14    5000.62
# 2024-02-15    5029.73
# 2024-02-16    5005.57
# 2024-02-19        NaN
# 2024-02-20    4975.51
# Length: 2608, dtype: float64

# %%
sp500.plot(figsize=(10,5), title="S&P 500 Trend", lw=1.5)
# Out:
# <AxesSubplot:title={'center':'S&P 500 Trend'}>

# %%
#pull and join mutiple data series

# %%
pop_res=fred.search("popularity")

# %%
unemp_res=fred.search("unemployment")

# %%
unemp_res
# Out:
#                               id realtime_start realtime_end  \
# series id
# UNRATE                    UNRATE     2024-02-21   2024-02-21
# UNRATENSA              UNRATENSA     2024-02-21   2024-02-21
# UNEMPLOY                UNEMPLOY     2024-02-21   2024-02-21
# CCSA                        CCSA     2024-02-21   2024-02-21
# NROU                        NROU     2024-02-21   2024-02-21
# ...                          ...            ...          ...
# LRSUR                      LRSUR     2024-02-21   2024-02-21
# LFUNTTTTITQ647S  LFUNTTTTITQ647S     2024-02-21   2024-02-21
# LRUNTTTTUSQ156S  LRUNTTTTUSQ156S     2024-02-21   2024-02-21
# BUFF336URN            BUFF336URN     2024-02-21   2024-02-21
# KNOX947UR              KNOX947UR     2024-02-21   2024-02-21
#
#                                                              title  \
# series id
# UNRATE                                           Unemployment Rate
# UNRATENSA                                        Unemployment Rate
# ...

# %%
unrate=fred.get_series("UNRATE")

# %%
unrate
# Out:
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
#              ...
# 2023-09-01    3.8
# 2023-10-01    3.8
# 2023-11-01    3.7
# 2023-12-01    3.7
# 2024-01-01    3.7
# Length: 913, dtype: float64
